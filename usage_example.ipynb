# %% [markdown]
# # Imports

# %%
from search import get_set, draw_set
import numpy as np

# %% [markdown]
# # Obtain a set for n

# %%
set_1 = [np.array([[1]])]
set_2 = get_set(set_1)
set_3 = get_set(set_2)
set_4 = get_set(set_3)
set_5 = get_set(set_4)
# set_6 = ...

# %% [markdown]
# # Draw a set

# %%
draw_set(set_4)
draw_set(set_5)

# %% [markdown]
# # Get the set for generic n

# %%
n = 4

prev_set = set_1
for _ in range(n-1):
    set_n = get_set(prev_set)
    prev_set = set_n

set_n
# Out:
# [array([[1., 0.],
#         [1., 1.],
#         [0., 1.]]),
#  array([[1., 1.],
#         [1., 1.]]),
#  array([[1., 1., 1.],
#         [0., 0., 1.]]),
#  array([[0., 1.],
#         [1., 1.],
#         [0., 1.]]),
#  array([[1.],
#         [1.],
#         [1.],
#         [1.]])]
